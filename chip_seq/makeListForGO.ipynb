# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.1     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.2     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
gfpanot <- read_tsv("/hdd/Itzel/NuevoTodo/deseq2_supportFiles_40/allPeaks_GFP_Annotated.tsv")
gfpbed <- read_tsv("/hdd/Itzel/NuevoTodo/bienPortadosDeseq_bed_41/bienPortadosDeseq_GFP.bed", col_names = F)
gfpbp <- as.vector(unlist(gfpbed$X4))
k27anot <- read_tsv("/hdd/Itzel/NuevoTodo/deseq2_supportFiles_40/allPeaks_K27_Annotated.tsv")
k27bed <- read_tsv("/hdd/Itzel/NuevoTodo/bienPortadosDeseq_bed_41/bienPortadosDeseq_K27.bed", col_names = F)
k27bp <- as.vector(unlist(k27bed$X4))
# Out:
# Rows: 6393 Columns: 14
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (6): Chrom, mockPeak_1, annotation, transcriptId, geneName, geneId
# dbl (8): Start, End, geneChr, geneStart, geneEnd, geneLength, geneStrand, di...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1100 Columns: 4
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (2): X1, X4
# dbl (2): X2, X3
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# ...

# %%
glimpse(gfpanot)
# Out:
# Rows: 6,393
# Columns: 14
# $ Chrom         <chr> "chr11", "chr6", "chr11", "chr11", "chr11", "chr11", "ch…
# $ Start         <dbl> 108343082, 17280956, 85837194, 85831915, 85888273, 85890…
# $ End           <dbl> 108343844, 17281329, 85838553, 85832591, 85888731, 85890…
# $ mockPeak_1    <chr> "mockPeak_906", "mockPeak_4657", "mockPeak_781", "mockPe…
# $ annotation    <chr> "Promoter (<=1kb)", "Promoter (<=1kb)", "Exon (ENSMUST00…
# $ geneChr       <dbl> 11, 6, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 6, 11, 7,…
# $ geneStart     <dbl> 108343354, 17281185, 85832551, 85832551, 85890063, 85890…
# $ geneEnd       <dbl> 108395905, 17289115, 85841948, 85841948, 85916097, 85916…
# $ geneLength    <dbl> 52552, 7931, 9398, 9398, 26035, 26035, 19331, 18918, 189…
# $ geneStrand    <dbl> 1, 1, 1, 1, 1, 1, 1, 2, 2, 1, 1, 1, 1, 2, 1, 1, 1, 1, 1,…
# $ transcriptId  <chr> "ENSMUST00000133383.7", "ENSMUST00000000058.6", "ENSMUST…
# ...

# %%
gfpanot_bp <-filter(gfpanot, mockPeak_1 %in% gfpbp)
k27anot_bp <-filter(k27anot, mockPeak_1 %in% k27bp)
gfpbp_genes <- unique(as.vector(unlist(gfpanot_bp$geneName)))
k27bp_genes <- unique(as.vector(unlist(k27anot_bp$geneName)))

write(gfpbp_genes, "/hdd/Itzel/NuevoTodo/listasNombresBienPortadosDeseqPara_GO_43/bienPortadosDeseq_GFP_geneNamesUnique.txt")
write(k27bp_genes, "/hdd/Itzel/NuevoTodo/listasNombresBienPortadosDeseqPara_GO_43/bienPortadosDeseq_K27_geneNamesUnique.txt")
write_tsv(gfpanot_bp, "/hdd/Itzel/NuevoTodo/listasNombresBienPortadosDeseqPara_GO_43/bienPortadosDeseq_GFP_Annotated.tsv")
write_tsv(k27anot_bp, "/hdd/Itzel/NuevoTodo/listasNombresBienPortadosDeseqPara_GO_43/bienPortadosDeseq_K27__Annotated.tsv")
